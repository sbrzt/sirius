# %%
import rdflib
from rdflib.plugins.sparql import prepareQuery
from tabulate import tabulate

# %%
filename = "ABox.ttl"

# %%
text1 = '''CQ_8.1
What are the statements assigned to the CHO `:baptistery` that are part of the assessment activity describing its context?
'''

query1 = '''
PREFIX tbox: <https://w3id.org/sirius/ontology/development/08/schema/>
PREFIX : <https://w3id.org/sirius/ontology/development/08/data/>

SELECT ?statement ?note ?agent ?document ?concept ?concept_type ?activity
WHERE {
    # ?activity a tbox:AssessmentActivity ;
        tbox:hasType tbox:context-description ; 
        tbox:assigns ?statement ;
        tbox:assignsTo :baptistery ;
        tbox:isCarriedOutBy ?agent .
    # ?statement tbox:hasContent ?note ;
        tbox:refersTo ?concept .
    # ?concept tbox:hasType ?concept_type .
    OPTIONAL {
        # ?statement tbox:isDocumentedBy ?document .
    }
}
'''

# %%
text2 = '''CQ_8.2
Which are the hazards, the types of risk occurence and the risk locations referred to by statements assigned to the CHO `:baptistery` by identification activities?
'''

query2 = '''
PREFIX tbox: <https://w3id.org/sirius/ontology/development/08/schema/>
PREFIX : <https://w3id.org/sirius/ontology/development/08/data/>

SELECT ?activity ?agent ?start_date ?end_date ?hazard_type ?occurrence_type ?location_type
WHERE {
  # ?activity a tbox:AssessmentActivity ;
    tbox:isCarriedOutBy ?agent ;
    tbox:hasType tbox:risk-identification ;
    tbox:atTime [ tbox:hasStartTime ?start_date ;
                  tbox:hasEndTime ?end_date ] ;
    tbox:assigns ?statement_1 ,
      # ?statement_2 ,
      # ?statement_3 .
  # ?statement_1 tbox:hasType tbox:condition-description ;
    tbox:refersTo [
        tbox:hasType ?hazard_type 
      ] .
  # ?statement_2 tbox:hasType tbox:dimensions-description ;
      tbox:refersTo [
        tbox:hasType ?occurrence_type 
      ] .
  # ?statement_3 tbox:hasType tbox:location-description ;
      tbox:refersTo [
        tbox:hasType ?location_type 
      ] .
}
'''

# %%
text3 = '''CQ_8.3
What are the low, probable and high estimates of the measures that are referred to by statements assigned to the CHO `:baptistery` by analysis activities?
'''

query3 = '''
PREFIX tbox: <https://w3id.org/sirius/ontology/development/08/schema/>
PREFIX : <https://w3id.org/sirius/ontology/development/08/data/>

SELECT ?activity ?statement ?type ?low_estimate_value ?prob_estimate_value ?high_estimate_value
WHERE {
  # ?activity a tbox:AssessmentActivity ;
    tbox:hasType tbox:risk-analysis ;
    tbox:assignsTo :baptistery ;
    tbox:assigns ?statement .
  # ?statement tbox:hasType tbox:dimensions-description ;
    tbox:refersTo ?concept .
  # ?concept tbox:hasType ?type ;
    tbox:isComposedOf ?low_estimate ,
      # ?prob_estimate , 
      # ?high_estimate .
  # ?low_estimate tbox:hasType tbox:low-estimate ;
    tbox:hasValue ?low_estimate_value .
  # ?prob_estimate tbox:hasType tbox:probable-estimate ;
    tbox:hasValue ?prob_estimate_value .
  # ?high_estimate tbox:hasType tbox:high-estimate ;
    tbox:hasValue ?high_estimate_value .
}
'''

# %%
text4 = '''CQ_8.4
What are the priority levels referred to by statements assigned to the CHO `:baptistery` by evaluation activities?
'''

query4 = '''
PREFIX tbox: <https://w3id.org/sirius/ontology/development/08/schema/>
PREFIX : <https://w3id.org/sirius/ontology/development/08/data/>

SELECT ?activity ?note ?priority_level
WHERE {
# ?activity a tbox:AssessmentActivity ;
  tbox:hasType tbox:risk-evaluation ;
  tbox:hasNote ?note ;
  tbox:assignsTo :baptistery ;
  tbox:assigns [
      tbox:hasType tbox:diagnosis ;
      tbox:refersTo [ 
        tbox:hasType ?priority_level 
      ]
  ]
}
'''

# %%
text5 = '''CQ_8.5
What are the treatment actions, capital costs and maintenance costs being referred to by the statements assigned to the CHO `:baptistery` by treatment activities?
'''

query5 = '''
PREFIX tbox: <https://w3id.org/sirius/ontology/development/08/schema/>
PREFIX : <https://w3id.org/sirius/ontology/development/08/data/>

SELECT ?activity ?note ?action ?capital_cost_value ?maintenance_cost_value
WHERE {
# ?activity a tbox:AssessmentActivity ;
  tbox:hasType tbox:risk-treatment ;
  tbox:hasNote ?note ;
  tbox:assignsTo :baptistery ;
  tbox:assigns ?statement_1 ,
    # ?statement_2 ,
    # ?statement_3 .
# ?statement_1 tbox:hasType tbox:plan ;
  tbox:refersTo ?concept_1 .
# ?concept_1 tbox:hasType ?action .
# ?statement_2 tbox:hasType tbox:budget ;
  tbox:refersTo ?capital_cost .
# ?capital_cost tbox:hasType tbox:capital-cost ;
    tbox:hasValue ?capital_cost_value .
# ?statement_3 tbox:hasType tbox:budget ;
  tbox:refersTo ?maintenance_cost .
# ?maintenance_cost tbox:hasType tbox:maintenance-cost ;
    tbox:hasValue ?maintenance_cost_value .
}
'''

# %%
queries = [(text1, query1),
           (text2, query2),
           (text3, query3),
           (text4, query4),
           (text5, query5)]

g = rdflib.ConjunctiveGraph()
g.parse(filename, format="turtle", encoding="utf-8")

for query in queries:
    q = prepareQuery(query[1])
    results = g.query(q)
    print(query[0])
    table = []
    for row in results:
        table.append([row[var] for var in results.vars])
    print(tabulate(table, headers=results.vars, tablefmt="psql"))
# Out:
# CQ_8.1
# What are the statements assigned to the CHO `:baptistery` that are part of the assessment activity describing its context?
#
# +---------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------+------------------------------------------------------------------+-----------------------------------------------------------------+----------------------------------------------------------------------------+-----------------------------------------------------------------------------+
# | statement                                                           | note                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         | agent                                                                | document                                                         | concept                                                         | concept_type                                                               | activity                                                                    |
# |---------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------+------------------------------------------------------------------+-----------------------------------------------------------------+----------------------------------------------------------------------------+-----------------------------------------------------------------------------|
# | https://w3id.org/sirius/ontology/development/08/data/observation-01 | The Baptistery is externally visible on the N, NW, and NE sides. The west side overlooks the gardens of a private residence, while the south, SW, and SE sides overlook the garden of the Department of Cultural Heritage (University of Bologna).                                                                                                                                                                                                                                                                           | https://w3id.org/sirius/ontology/development/08/data/sara-fiorentino |                                                                  | https://w3id.org/sirius/ontology/development/08/data/concept-01 | https://w3id.org/sirius/ontology/development/08/schema/physical-properties | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-01 |
# | https://w3id.org/sirius/ontology/development/08/data/observation-02 | Monumental site in an urban area, open to tourists (with prior admission ticket). The small square where the building is located suffers from a bad reputation, being labeled as a 'socially risky area and a neglected place' (reported incident of an abandoned bed frame found at night in the Baptistery's trench, 11.07.2006, Source: Zaccarini, 2015). Despite the establishment of regulations in 2012 restricting vehicle access to the square, transit and parking for loading/unloading goods are still permitted. | https://w3id.org/sirius/ontology/development/08/data/sara-fiorentino |                                                                  | https://w3id.org/sirius/ontology/development/08/data/concept-02 | https://w3id.org/sirius/ontology/development/08/schema/society             | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-01 |
# | https://w3id.org/sirius/ontology/development/08/data/observation-03 | The monument is often a subject of debate among various political parties and the Municipality of Ravenna.                                                                                                                                                                                                                                                                                                                                                                                                                   | https://w3id.org/sirius/ontology/development/08/data/sara-fiorentino | https://w3id.org/sirius/ontology/development/08/data/document-01 | https://w3id.org/sirius/ontology/development/08/data/concept-03 | https://w3id.org/sirius/ontology/development/08/schema/politics            | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-01 |
# | https://w3id.org/sirius/ontology/development/08/data/observation-04 | Owned by the State Property / Ministry of Culture. Since 1996, it has been part of the UNESCO World Heritage Sites list in Italy ('Early Christian Monuments of Ravenna').                                                                                                                                                                                                                                                                                                                                                   | https://w3id.org/sirius/ontology/development/08/data/sara-fiorentino |                                                                  | https://w3id.org/sirius/ontology/development/08/data/concept-04 | https://w3id.org/sirius/ontology/development/08/schema/legal-status        | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-01 |
# | https://w3id.org/sirius/ontology/development/08/data/observation-05 | Since December 2019, it has been managed by the Regional Directorate of Museums of Emilia Romagna, located in Ravenna.                                                                                                                                                                                                                                                                                                                                                                                                       | https://w3id.org/sirius/ontology/development/08/data/sara-fiorentino |                                                                  | https://w3id.org/sirius/ontology/development/08/data/concept-05 | https://w3id.org/sirius/ontology/development/08/schema/administration      | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-01 |
# | https://w3id.org/sirius/ontology/development/08/data/observation-06 | The Law No. 77 of February 20, 2006, establishes that UNESCO sites are excellences of the Italian cultural, landscape, and natural heritage, fundamental elements of our country's representation at the international level, and states that interventions on them have priority even in terms of the allocation of financial resources.                                                                                                                                                                                    | https://w3id.org/sirius/ontology/development/08/data/sara-fiorentino |                                                                  | https://w3id.org/sirius/ontology/development/08/data/concept-06 | https://w3id.org/sirius/ontology/development/08/schema/economics           | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-01 |
# +---------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------+------------------------------------------------------------------+-----------------------------------------------------------------+----------------------------------------------------------------------------+-----------------------------------------------------------------------------+
# CQ_8.2
# Which are the hazards, the types of risk occurence and the risk locations referred to by statements assigned to the CHO `:baptistery` by identification activities?
#
# +-----------------------------------------------------------------------------+----------------------------------------------------------------------+----------------------+----------------------+---------------------------------------------------------------------+-------------------------------------------------------------------+-----------------------------------------------------------------+
# | activity                                                                    | agent                                                                | start_date           | end_date             | hazard_type                                                         | occurrence_type                                                   | location_type                                                   |
# |-----------------------------------------------------------------------------+----------------------------------------------------------------------+----------------------+----------------------+---------------------------------------------------------------------+-------------------------------------------------------------------+-----------------------------------------------------------------|
# | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-03 | https://w3id.org/sirius/ontology/development/08/data/sara-fiorentino | 2024-03-01T00:00:00Z | 2024-04-01T23:59:59Z | https://w3id.org/sirius/ontology/development/08/schema/water-damage | https://w3id.org/sirius/ontology/development/08/schema/annual     | https://w3id.org/sirius/ontology/development/08/schema/region   |
# | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-04 | https://w3id.org/sirius/ontology/development/08/data/sara-fiorentino | 2024-03-01T00:00:00Z | 2024-04-01T23:59:59Z | https://w3id.org/sirius/ontology/development/08/schema/fire-damage  | https://w3id.org/sirius/ontology/development/08/schema/centennial | https://w3id.org/sirius/ontology/development/08/schema/building |
# +-----------------------------------------------------------------------------+----------------------------------------------------------------------+----------------------+----------------------+---------------------------------------------------------------------+-------------------------------------------------------------------+-----------------------------------------------------------------+
# CQ_8.3
# What are the low, probable and high estimates of the measures that are referred to by statements assigned to the CHO `:baptistery` by analysis activities?
#
# +-----------------------------------------------------------------------------+---------------------------------------------------------------------+------------------------------------------------------------------------------+----------------------+-----------------------+-----------------------+
# | activity                                                                    | statement                                                           | type                                                                         |   low_estimate_value |   prob_estimate_value |   high_estimate_value |
# |-----------------------------------------------------------------------------+---------------------------------------------------------------------+------------------------------------------------------------------------------+----------------------+-----------------------+-----------------------|
# | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-05 | https://w3id.org/sirius/ontology/development/08/data/observation-16 | https://w3id.org/sirius/ontology/development/08/schema/frequency             |                  3   |                   3.5 |                   4   |
# | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-05 | https://w3id.org/sirius/ontology/development/08/data/observation-17 | https://w3id.org/sirius/ontology/development/08/schema/fractional-value-loss |                  4.5 |                   5   |                   5   |
# | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-05 | https://w3id.org/sirius/ontology/development/08/data/observation-18 | https://w3id.org/sirius/ontology/development/08/schema/exposure              |                  1.5 |                   2   |                   2.5 |
# | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-05 | https://w3id.org/sirius/ontology/development/08/data/observation-19 | https://w3id.org/sirius/ontology/development/08/schema/risk-magnitude        |                  9   |                  10.5 |                  11.5 |
# | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-06 | https://w3id.org/sirius/ontology/development/08/data/observation-20 | https://w3id.org/sirius/ontology/development/08/schema/frequency             |                  2   |                   2.5 |                   3   |
# | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-06 | https://w3id.org/sirius/ontology/development/08/data/observation-21 | https://w3id.org/sirius/ontology/development/08/schema/fractional-value-loss |                  4.5 |                   5   |                   5   |
# | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-06 | https://w3id.org/sirius/ontology/development/08/data/observation-22 | https://w3id.org/sirius/ontology/development/08/schema/exposure              |                  4.5 |                   5   |                   5   |
# | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-06 | https://w3id.org/sirius/ontology/development/08/data/observation-23 | https://w3id.org/sirius/ontology/development/08/schema/risk-magnitude        |                 11   |                  12.5 |                  13   |
# +-----------------------------------------------------------------------------+---------------------------------------------------------------------+------------------------------------------------------------------------------+----------------------+-----------------------+-----------------------+
# CQ_8.4
# What are the priority levels referred to by statements assigned to the CHO `:baptistery` by evaluation activities?
#
# +-----------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------+
# | activity                                                                    | note                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               | priority_level                                                                |
# |-----------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------|
# | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-07 | The risk of flood (MR = 10.5) has a high priority. It is 100 times smaller than the fire risk. The uncertainty that has been measured amounts to a value equal to 2.5. A risk of this magnitude is equivalent to losing about 0.3% of the heritage asset value every 100 years (or 3% per millennium). The museum direction considers this level of risk as just beyond acceptable, since as a condition the value of MR is slightly higher than 10 and the value of uncertainty is higher than 2.                 | https://w3id.org/sirius/ontology/development/08/schema/high-priority-level    |
# | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-08 | The risk of a large fire affecting the baptistery and its contents (MR = 12.5) has an extreme priority. The uncertainty that has been measured amounts to a value equal to 1.0. A risk of this magnitude is equivalent to losing about 3% of the heritage asset value every 10 years (or 30% per century, or 100% in about 300 years). The museum direction considers this level of risk as ‘not acceptable’, since as a condition the value of MR is higher than 10 and the value of uncertainty is lower than 2. | https://w3id.org/sirius/ontology/development/08/schema/extreme-priority-level |
# +-----------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------+
# CQ_8.5
# What are the treatment actions, capital costs and maintenance costs being referred to by the statements assigned to the CHO `:baptistery` by treatment activities?
#
# +-----------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------+----------------------+--------------------------+
# | activity                                                                    | note                                                                                                                                                                                                                                                                                                                                                                | action                                                       |   capital_cost_value |   maintenance_cost_value |
# |-----------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------+----------------------+--------------------------|
# | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-09 | One possible action to protect a baptistery from water damage could be to install a waterproof membrane or coating on the exterior surfaces. This would help prevent water infiltration and damage to the structure. Additionally, regular maintenance such as inspecting for cracks or leaks and repairing them promptly can help mitigate water damage over time. | https://w3id.org/sirius/ontology/development/08/schema/block |                 3200 |                      120 |
# | https://w3id.org/sirius/ontology/development/08/data/assessment-activity-10 | Use fire-resistant materials: Consider using fire-resistant coatings, fire-rated doors, and fireproof insulation to minimize fire damage.                                                                                                                                                                                                                           | https://w3id.org/sirius/ontology/development/08/schema/block |                 5000 |                      375 |
# +-----------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------+----------------------+--------------------------+
