# %%
import rdflib
from rdflib.plugins.sparql import prepareQuery
from tabulate import tabulate

# %%
filename = "../../data/01/ABox.ttl"

# %%
text1 = '''CQ_1.1
What information should be returned about the heritage asset, including its name, alternative name, description, location (along with coordinates), and the temporal horizon specifying the creation event date?
'''

query1 = '''
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX hero: <https://w3id.org/sirius/ontology/hero/>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?asset_name ?alt_name ?description ?place_name ?coordinates ?date
WHERE {
    # ?heritage_asset a crm:E24_Physical_Human-Made_Thing ;
                    dcterms:title ?asset_name ;
                    dcterms:alternative ?alt_name ;
                    hero:hasNote ?description ;
                    crm:P55_has_current_location ?place .
    # ?place a crm:E53_Place ;
            rdfs:label ?place_name ;
            crm:P168_place_is_defined_by ?coordinates .
    # ?creation_event a crm:E12_Production ;
                    crm:P108_has_produced ?heritage_asset ;
                    crm:P4_has_time-span ?time_span .
    # ?time_span a crm:E52_Time-Span ;
                crm:P82_at_some_time_within ?date .
}
'''

# %%
text2 = '''CQ_1.2
What is the contextual information of the heritage asset in terms of its type and description?
'''

query2 = '''
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX hero: <https://w3id.org/sirius/ontology/hero/>

SELECT ?heritage_asset ?context_type ?context_description
WHERE {
    # ?heritage_asset a crm:E24_Physical_Human-Made_Thing .
    # ?riskAssessment a hero:ContextDescription ;
                    hero:describes ?heritage_asset ;
                    hero:hasObservation ?context .
    # ?context a hero:Observation ;
                hero:hasParameter ?context_type ;
                hero:hasNote ?context_description .
}
'''

# %%
text3 = '''CQ_1.3
Which documents provide information about the contextual details of the heritage asset?
'''

query3 = '''
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX hero: <https://w3id.org/sirius/ontology/hero/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?heritage_asset ?context_type ?document ?document_link
WHERE {
    # ?heritage_asset a crm:E24_Physical_Human-Made_Thing .
    # ?riskAssessment a hero:ContextDescription ;
                    hero:describes ?heritage_asset ;
                    hero:hasObservation ?context .
    # ?context a hero:Observation ;
                hero:hasParameter ?context_type .
    # ?document a foaf:Document ;
                hero:documents ?context ;
                rdfs:seeAlso ?document_link .
}
'''

# %%
text4 = '''CQ_1.4
Who are the stakeholders involved in the risk assessment activity related to the heritage asset, and what are their names?
'''

query4 = '''
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX hero: <https://w3id.org/sirius/ontology/hero/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>

SELECT ?heritage_asset ?stakeholder_name
WHERE {
    # ?heritage_asset a crm:E24_Physical_Human-Made_Thing .
    # ?risk_assessment_activity a hero:ContextDescription ;
                                hero:describes ?heritage_asset ;
                                hero:hasParticipant ?stakeholder .
    # ?stakeholder a foaf:Agent ;
                foaf:name ?stakeholder_name .
}
'''

# %%
queries = [(text1, query1),
           (text2, query2),
           (text3, query3),
           (text4, query4)]

g = rdflib.ConjunctiveGraph()
g.parse(filename, format="turtle", encoding="utf-8")

for query in queries:
    q = prepareQuery(query[1])
    results = g.query(q)
    print(query[0])
    table = []
    for row in results:
        table.append([row[var] for var in results.vars])
    print(tabulate(table, headers=results.vars, tablefmt="psql"))
# Out:
# CQ_1.1
# Return the information about the heritage asset, including its name, alternative name, its description, the place it is located in (as well as its coordinates), and the time-span temporal horizon that identifies the creation event it has been dated to.
#
# +-------------------------+-------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------+--------------------------------------+-------------------------+
# | asset_name              | alt_name                            | description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      | place_name                            | coordinates                          | date                    |
# |-------------------------+-------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------+--------------------------------------+-------------------------|
# | Battistero degli Ariani | Oratorio di Santa Maria in Cosmedin | Edificio a pianta ottagonale con copertura a spioventi, presenta quattro absidiole in corrispondenza dei punti cardinali (parzialmente interrate). La decorazione musiva è conservata sulla sola cupola, creando un sorprendente contrasto con la superficie grezza dei mattoni a vista nella parte inferiore. Il mosaico rappresenta al centro il battesimo di Cristo nel fiume Giordano, attorno ad esso una fascia con i dodici apostoli che sfilano in due teorie, incontrandosi presso il trono dell'etimasìa, simbolo della presenza invisibile di Cristo. | Piazzetta degli Ariani, 48121 Ravenna | 44.41871491574331, 12.20247187841604 | Late fifth century A.D. |
# +-------------------------+-------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------+--------------------------------------+-------------------------+
# CQ_1.2
# Return the contextual information of the heritage asset in terms of its type and description.
#
# +----------------------------------------------------+-----------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | heritage_asset                                     | context_type                                        | context_description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |----------------------------------------------------+-----------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | https://w3id.org/sirius/ontology/data/01/baptistery | https://w3id.org/sirius/ontology/hero/administrative | Dal dicembre 2019 è gestito da Direzione regionale Musei dell’Emilia Romagna, sede di Ravenna.                                                                                                                                                                                                                                                                                                                                                                                                                         |
# | https://w3id.org/sirius/ontology/data/01/baptistery | https://w3id.org/sirius/ontology/hero/economic       | La Legge n. 77 del 20 febbraio 2006, stabilisce che i siti UNESCO sono eccellenze del Patrimonio culturale, paesaggistico e naturale italiano, elementi fondanti della rappresentazione del nostro Paese a livello internazionale e afferma che gli interventi su di essi hanno la priorità anche in ordine all'assegnazione delle risorse finanziarie                                                                                                                                                                 |
# | https://w3id.org/sirius/ontology/data/01/baptistery | https://w3id.org/sirius/ontology/hero/legal          | Di proprietà del Demanio di Stato / MiC. Dal 1996 fa parte della lista dei siti italiani patrimonio dell'umanità UNESCO («Monumenti paleocristiani di Ravenna»).                                                                                                                                                                                                                                                                                                                                                       |
# | https://w3id.org/sirius/ontology/data/01/baptistery | https://w3id.org/sirius/ontology/hero/physical       | Il Battistero è visibile esternamente sui lati N, NO, NE. Il lato O affaccia sui giardini di un’abitazione privata, mentre i lati S, SO, SE, affacciano sul giardino del Dipartimento di Beni Culturali (Università di Bologna).                                                                                                                                                                                                                                                                                       |
# | https://w3id.org/sirius/ontology/data/01/baptistery | https://w3id.org/sirius/ontology/hero/political      | Il monumento è spesso motivo di dibattito tra i vari partiti ed il Comune di Ravenna                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# | https://w3id.org/sirius/ontology/data/01/baptistery | https://w3id.org/sirius/ontology/hero/socio-cultural | Sito monumentale di area urbana, visitabile dai turisti (previo biglietto d’ingresso). La Piazzetta in cui è collocato l’edificio risente di una cattiva fama, in quanto “zona a rischio sociale e luogo dimesso” (si riporta il caso di una rete da letto abbandonata di notte nella trincea del Battistero, 11.07.2006, Fonte: Zaccarini, 2015). Nonostante l’istituzione nel 2012 di una regolamentazione all’accesso dei veicoli alla Piazzetta, resta consentito il transito e la sosta per carico/scarico merci. |
# +----------------------------------------------------+-----------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# CQ_1.3
# Return the documents that document the contextual information of the heritage asset.
#
# +----------------------------------------------------+------------------------------------------------+---------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+
# | heritage_asset                                     | context_type                                   | document                                                      | document_link                                                                                                                |
# |----------------------------------------------------+------------------------------------------------+---------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------|
# | https://w3id.org/sirius/ontology/data/01/baptistery | https://w3id.org/sirius/ontology/hero/political | https://w3id.org/sirius/ontology/data/01/document-1-baptistery | http://www.ravennaincomune.it/wp/index.php/2020/05/23/telecamere-di-sorveglianza-allassalto-del-battistero-degli-ariani      |
# | https://w3id.org/sirius/ontology/data/01/baptistery | https://w3id.org/sirius/ontology/hero/political | https://w3id.org/sirius/ontology/data/01/document-2-baptistery | https://www.ravennatoday.it/cronaca/telecamere-nelle-millenarie-mura-del-battistero-degli-ariani-protesta-italia-nostra.html |
# | https://w3id.org/sirius/ontology/data/01/baptistery | https://w3id.org/sirius/ontology/hero/political | https://w3id.org/sirius/ontology/data/01/document-3-baptistery | https://www.ravennaedintorni.it/societa/2020/05/30/telecamere-battistero-ariani/                                             |
# | https://w3id.org/sirius/ontology/data/01/baptistery | https://w3id.org/sirius/ontology/hero/political | https://w3id.org/sirius/ontology/data/01/document-4-baptistery | https://www.ravennanotizie.it/cultura-spettacolo/2020/05/30/                                                                 |
# | https://w3id.org/sirius/ontology/data/01/baptistery | https://w3id.org/sirius/ontology/hero/political | https://w3id.org/sirius/ontology/data/01/document-5-baptistery | https://www.corriereromagna.it/ravenna-telecamere-installate-nelle-millenarie-mura-del-battistero/                           |
# +----------------------------------------------------+------------------------------------------------+---------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------+
# CQ_1.4
# Return the names of the stakeholders involved in the risk assessment activity regarding the heritage asset.
#
# +----------------------------------------------------+-----------------------+
# | heritage_asset                                     | stakeholder_name      |
# |----------------------------------------------------+-----------------------|
# | https://w3id.org/sirius/ontology/data/01/baptistery | Cittadinanza          |
# | https://w3id.org/sirius/ontology/data/01/baptistery | Comune di Ravenna     |
# | https://w3id.org/sirius/ontology/data/01/baptistery | Fondazioni locali     |
# | https://w3id.org/sirius/ontology/data/01/baptistery | Soprintendenza        |
# | https://w3id.org/sirius/ontology/data/01/baptistery | Turisti               |
# | https://w3id.org/sirius/ontology/data/01/baptistery | Università di Bologna |
# +----------------------------------------------------+-----------------------+
