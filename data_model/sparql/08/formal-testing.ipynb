# %%
import rdflib
from rdflib.plugins.sparql import prepareQuery
from tabulate import tabulate

# %%
filename = "../../data/08/ABox.ttl"

# %%
text1 = '''CQ_8.1
What are the statements assigned to a CHO that are part of the assessment activity describing its context?
'''

query1 = '''
PREFIX : <https://w3id.org/sirius/ontology/data/08/>
PREFIX hero: <https://w3id.org/sirius/ontology/hero/>
PREFIX ti: <http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#>
PREFIX wd: <http://www.wikidata.org/entity/>

SELECT ?statement ?note ?document ?concept ?concept_type ?activity ?agent ?place ?start_date ?end_date
WHERE {
    # ?activity a hero:Activity ;
        hero:hasType wd:Q1137655 ; 
        hero:assigns ?statement ;
        hero:hasTimeInterval [ ti:hasIntervalStartDate ?start_date ;
            ti:hasIntervalEndDate ?end_date ] ;
        hero:hasLocation ?place ;
        hero:isCarriedOutBy ?agent .
    # ?statement hero:hasContent ?note ;
        hero:refersTo ?concept .
    # ?concept hero:hasType ?concept_type .
    OPTIONAL {
        # ?statement hero:isDocumentedBy ?document .
    }
}

'''

# %%
text2 = '''CQ_8.2
Which are the hazards, the types of risk occurence and the risk locations referred to by statements assigned to a CHO by identification activities?
'''

query2 = '''
PREFIX : <https://w3id.org/sirius/ontology/data/08/>
PREFIX aat: <http://vocab.getty.edu/page/aat/>
PREFIX hero: <https://w3id.org/sirius/ontology/hero/>
PREFIX ti: <http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#>
PREFIX wd: <http://www.wikidata.org/entity/>

SELECT ?activity ?hazard_type ?occurrence_type ?location_type ?agent ?place ?start_date ?end_date
WHERE {
  # ?activity a hero:Activity ;
    hero:isCarriedOutBy ?agent ;
    hero:hasType wd:Q5687675 ;
    hero:hasTimeInterval [ ti:hasIntervalStartDate ?start_date ;
      ti:hasIntervalEndDate ?end_date ] ;
    hero:hasLocation ?place ;
    hero:assigns ?statement_1 ,
      # ?statement_2 ,
      # ?statement_3 .
  # ?statement_1 hero:hasType aat:300435425 ;
    hero:refersTo [
        hero:hasType ?hazard_type 
      ] .
  # ?statement_2 hero:hasType aat:300435430 ;
      hero:refersTo [
        hero:hasType ?occurrence_type 
      ] .
  # ?statement_3 hero:hasType aat:300435449 ;
      hero:refersTo [
        hero:hasType ?location_type 
      ] .
}
'''

# %%
text3 = '''CQ_8.3
What are the low, probable and high estimates of the measures that are referred to by statements assigned to a CHO by analysis activities?
'''

query3 = '''
PREFIX : <https://w3id.org/sirius/ontology/data/08/>
PREFIX aat: <http://vocab.getty.edu/page/aat/>
PREFIX hero: <https://w3id.org/sirius/ontology/hero/>
PREFIX ti: <http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#>
PREFIX wd: <http://www.wikidata.org/entity/>

SELECT DISTINCT ?activity ?statement ?type ?low_estimate_value ?prob_estimate_value ?high_estimate_value ?agent ?place ?start_date ?end_date
WHERE {
  # ?activity a hero:Activity ;
    hero:hasType wd:Q217602 ;
    hero:isCarriedOutBy ?agent ;
    hero:hasTimeInterval [ ti:hasIntervalStartDate ?start_date ;
      ti:hasIntervalEndDate ?end_date ] ;
    hero:hasLocation ?place ;
    hero:assigns ?statement .
  # ?statement hero:hasType aat:300435430 ;
    hero:refersTo ?concept .
  # ?concept hero:hasType ?type ;
    hero:hasComponent ?low_estimate ,
      # ?prob_estimate , 
      # ?high_estimate .
  # ?low_estimate hero:hasType wd:Q10585806 ;
    hero:hasContent ?low_estimate_value .
  # ?prob_estimate hero:hasType wd:Q226995 ;
    hero:hasContent ?prob_estimate_value .
  # ?high_estimate hero:hasType wd:Q10578722 ;
    hero:hasContent ?high_estimate_value .
}
'''

# %%
text4 = '''CQ_8.4
What are the priority levels referred to by statements assigned to a CHO by evaluation activities?
'''

query4 = '''
PREFIX : <https://w3id.org/sirius/ontology/data/08/>
PREFIX aat: <http://vocab.getty.edu/page/aat/>
PREFIX hero: <https://w3id.org/sirius/ontology/hero/>
PREFIX ti: <http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#>
PREFIX wd: <http://www.wikidata.org/entity/>

SELECT ?activity ?note ?priority_level ?agent ?place ?start_date ?end_date
WHERE {
# ?activity a hero:Activity ;
  hero:hasType wd:Q1379672 ;
  hero:hasNote ?note ;
  hero:isCarriedOutBy ?agent ;
  hero:hasTimeInterval [ ti:hasIntervalStartDate ?start_date ;
      ti:hasIntervalEndDate ?end_date ] ;
  hero:hasLocation ?place ;
  hero:assigns [
      hero:hasType aat:300438433 ;
      hero:refersTo [ 
        hero:hasType ?priority_level 
      ]
  ]
}
'''

# %%
text5 = '''CQ_8.5
What are the treatment actions, capital costs and maintenance costs being referred to by the statements assigned to a CHO by treatment activities?
'''

query5 = '''
PREFIX : <https://w3id.org/sirius/ontology/data/08/>
PREFIX aat: <http://vocab.getty.edu/page/aat/>
PREFIX hero: <https://w3id.org/sirius/ontology/hero/>
PREFIX ti: <http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#>
PREFIX wd: <http://www.wikidata.org/entity/>

SELECT DISTINCT ?activity ?note ?action ?capital_cost_value ?maintenance_cost_value ?agent ?place ?start_date ?end_date
WHERE {
  # ?activity a hero:Activity ;
    hero:hasType wd:Q2251595 ;
    hero:hasNote ?note ;
    hero:isCarriedOutBy ?agent ;
    hero:hasTimeInterval [ ti:hasIntervalStartDate ?start_date ;
      ti:hasIntervalEndDate ?end_date ] ;
    hero:hasLocation ?place ;
    hero:assigns ?statement_1 ,
      # ?statement_2 ,
      # ?statement_3 .
  # ?statement_1 hero:hasType wd:Q1371819 ;
    hero:refersTo ?concept_1 .
  # ?concept_1 hero:hasType ?action .
  # ?statement_2 hero:hasType aat:300027514 ;
    hero:refersTo ?capital_cost .
  # ?capital_cost hero:hasType wd:Q302208 ;
    hero:hasContent ?capital_cost_value .
  # ?statement_3 hero:hasType aat:300027514 ;
    hero:refersTo ?maintenance_cost .
  # ?maintenance_cost hero:hasType wd:Q831940 ;
    hero:hasContent ?maintenance_cost_value .
}
'''

# %%
queries = [(text1, query1),
           (text2, query2),
           (text3, query3),
           (text4, query4),
           (text5, query5)]

g = rdflib.ConjunctiveGraph()
g.parse(filename, format="turtle", encoding="utf-8")

for query in queries:
    q = prepareQuery(query[1])
    results = g.query(q)
    print(query[0])
    table = []
    for row in results:
        table.append([row[var] for var in results.vars])
    print(tabulate(table, headers=results.vars, tablefmt="psql"))
# Out:
# CQ_8.1
# What are the statements assigned to a CHO that are part of the assessment activity describing its context?
#
# +---------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-----------------------------------------------------+-----------------------------------------+-----------------------------------------------------------------+----------------------------------------------------------+--------------------------------------------------+----------------------+----------------------+
# | statement                                               | note                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         | document                                             | concept                                             | concept_type                            | activity                                                        | agent                                                    | place                                            | start_date           | end_date             |
# |---------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-----------------------------------------------------+-----------------------------------------+-----------------------------------------------------------------+----------------------------------------------------------+--------------------------------------------------+----------------------+----------------------|
# | https://w3id.org/sirius/ontology/data/08/observation-01 | The Baptistery is externally visible on the N, NW, and NE sides. The west side overlooks the gardens of a private residence, while the south, SW, and SE sides overlook the garden of the Department of Cultural Heritage (University of Bologna).                                                                                                                                                                                                                                                                           |                                                      | https://w3id.org/sirius/ontology/data/08/concept-01 | http://www.wikidata.org/entity/Q4373292 | https://w3id.org/sirius/ontology/data/08/assessment-activity-01 | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-02-01T00:00:00Z | 2024-03-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/data/08/observation-02 | Monumental site in an urban area, open to tourists (with prior admission ticket). The small square where the building is located suffers from a bad reputation, being labeled as a 'socially risky area and a neglected place' (reported incident of an abandoned bed frame found at night in the Baptistery's trench, 11.07.2006, Source: Zaccarini, 2015). Despite the establishment of regulations in 2012 restricting vehicle access to the square, transit and parking for loading/unloading goods are still permitted. |                                                      | https://w3id.org/sirius/ontology/data/08/concept-02 | http://www.wikidata.org/entity/Q8425    | https://w3id.org/sirius/ontology/data/08/assessment-activity-01 | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-02-01T00:00:00Z | 2024-03-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/data/08/observation-03 | The monument is often a subject of debate among various political parties and the Municipality of Ravenna.                                                                                                                                                                                                                                                                                                                                                                                                                   | https://w3id.org/sirius/ontology/data/08/document-01 | https://w3id.org/sirius/ontology/data/08/concept-03 | http://www.wikidata.org/entity/Q7163    | https://w3id.org/sirius/ontology/data/08/assessment-activity-01 | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-02-01T00:00:00Z | 2024-03-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/data/08/observation-04 | Owned by the State Property / Ministry of Culture. Since 1996, it has been part of the UNESCO World Heritage Sites list in Italy ('Early Christian Monuments of Ravenna').                                                                                                                                                                                                                                                                                                                                                   |                                                      | https://w3id.org/sirius/ontology/data/08/concept-04 | http://www.wikidata.org/entity/Q2628882 | https://w3id.org/sirius/ontology/data/08/assessment-activity-01 | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-02-01T00:00:00Z | 2024-03-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/data/08/observation-05 | Since December 2019, it has been managed by the Regional Directorate of Museums of Emilia Romagna, located in Ravenna.                                                                                                                                                                                                                                                                                                                                                                                                       |                                                      | https://w3id.org/sirius/ontology/data/08/concept-05 | http://www.wikidata.org/entity/Q5283295 | https://w3id.org/sirius/ontology/data/08/assessment-activity-01 | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-02-01T00:00:00Z | 2024-03-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/data/08/observation-06 | The Law No. 77 of February 20, 2006, establishes that UNESCO sites are excellences of the Italian cultural, landscape, and natural heritage, fundamental elements of our country's representation at the international level, and states that interventions on them have priority even in terms of the allocation of financial resources.                                                                                                                                                                                    |                                                      | https://w3id.org/sirius/ontology/data/08/concept-06 | http://www.wikidata.org/entity/Q8134    | https://w3id.org/sirius/ontology/data/08/assessment-activity-01 | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-02-01T00:00:00Z | 2024-03-01T23:59:59Z |
# +---------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-----------------------------------------------------+-----------------------------------------+-----------------------------------------------------------------+----------------------------------------------------------+--------------------------------------------------+----------------------+----------------------+
# CQ_8.2
# Which are the hazards, the types of risk occurence and the risk locations referred to by statements assigned to a CHO by identification activities?
#
# +-----------------------------------------------------------------+------------------------------------------+-------------------------------------------------------------------+---------------------------------------+----------------------------------------------------------+--------------------------------------------------+----------------------+----------------------+
# | activity                                                        | hazard_type                              | occurrence_type                                                   | location_type                         | agent                                                    | place                                            | start_date           | end_date             |
# |-----------------------------------------------------------------+------------------------------------------+-------------------------------------------------------------------+---------------------------------------+----------------------------------------------------------+--------------------------------------------------+----------------------+----------------------|
# | https://w3id.org/sirius/ontology/data/08/assessment-activity-03 | http://www.wikidata.org/entity/Q19289049 | http://publications.europa.eu/resource/authority/frequency/ANNUAL | http://www.wikidata.org/entity/Q82794 | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-03-01T00:00:00Z | 2024-04-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/data/08/assessment-activity-04 | http://www.wikidata.org/entity/Q56497979 | http://publications.europa.eu/resource/authority/frequency/OTHER  | http://www.wikidata.org/entity/Q41176 | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-03-01T00:00:00Z | 2024-04-01T23:59:59Z |
# +-----------------------------------------------------------------+------------------------------------------+-------------------------------------------------------------------+---------------------------------------+----------------------------------------------------------+--------------------------------------------------+----------------------+----------------------+
# CQ_8.3
# What are the low, probable and high estimates of the measures that are referred to by statements assigned to a CHO by analysis activities?
#
# +-----------------------------------------------------------------+---------------------------------------------------------+-------------------------------------------+----------------------+-----------------------+-----------------------+----------------------------------------------------------+--------------------------------------------------+----------------------+----------------------+
# | activity                                                        | statement                                               | type                                      |   low_estimate_value |   prob_estimate_value |   high_estimate_value | agent                                                    | place                                            | start_date           | end_date             |
# |-----------------------------------------------------------------+---------------------------------------------------------+-------------------------------------------+----------------------+-----------------------+-----------------------+----------------------------------------------------------+--------------------------------------------------+----------------------+----------------------|
# | https://w3id.org/sirius/ontology/data/08/assessment-activity-05 | https://w3id.org/sirius/ontology/data/08/observation-16 | http://www.wikidata.org/entity/Q11652     |                  3   |                   3.5 |                   4   | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-04-01T00:00:00Z | 2024-05-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/data/08/assessment-activity-05 | https://w3id.org/sirius/ontology/data/08/observation-17 | http://www.wikidata.org/entity/Q7523953   |                  4.5 |                   5   |                   5   | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-04-01T00:00:00Z | 2024-05-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/data/08/assessment-activity-05 | https://w3id.org/sirius/ontology/data/08/observation-18 | http://www.wikidata.org/entity/Q107642367 |                  1.5 |                   2   |                   2.5 | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-04-01T00:00:00Z | 2024-05-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/data/08/assessment-activity-05 | https://w3id.org/sirius/ontology/data/08/observation-19 | http://www.wikidata.org/entity/Q2154759   |                  9   |                  10.5 |                  11.5 | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-04-01T00:00:00Z | 2024-05-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/data/08/assessment-activity-06 | https://w3id.org/sirius/ontology/data/08/observation-20 | http://www.wikidata.org/entity/Q11652     |                  2   |                   2.5 |                   3   | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-04-01T00:00:00Z | 2024-05-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/data/08/assessment-activity-06 | https://w3id.org/sirius/ontology/data/08/observation-21 | http://www.wikidata.org/entity/Q7523953   |                  4.5 |                   5   |                   5   | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-04-01T00:00:00Z | 2024-05-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/data/08/assessment-activity-06 | https://w3id.org/sirius/ontology/data/08/observation-22 | http://www.wikidata.org/entity/Q107642367 |                  4.5 |                   5   |                   5   | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-04-01T00:00:00Z | 2024-05-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/data/08/assessment-activity-06 | https://w3id.org/sirius/ontology/data/08/observation-23 | http://www.wikidata.org/entity/Q2154759   |                 11   |                  12.5 |                  13   | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-04-01T00:00:00Z | 2024-05-01T23:59:59Z |
# +-----------------------------------------------------------------+---------------------------------------------------------+-------------------------------------------+----------------------+-----------------------+-----------------------+----------------------------------------------------------+--------------------------------------------------+----------------------+----------------------+
# CQ_8.4
# What are the priority levels referred to by statements assigned to a CHO by evaluation activities?
#
# +-----------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------+----------------------------------------------------------+--------------------------------------------------+----------------------+----------------------+
# | activity                                                        | note                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               | priority_level                            | agent                                                    | place                                            | start_date           | end_date             |
# |-----------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------+----------------------------------------------------------+--------------------------------------------------+----------------------+----------------------|
# | https://w3id.org/sirius/ontology/data/08/assessment-activity-07 | The risk of flood (MR = 10.5) has a high priority. It is 100 times smaller than the fire risk. The uncertainty that has been measured amounts to a value equal to 2.5. A risk of this magnitude is equivalent to losing about 0.3% of the heritage asset value every 100 years (or 3% per millennium). The museum direction considers this level of risk as just beyond acceptable, since as a condition the value of MR is slightly higher than 10 and the value of uncertainty is higher than 2.                 | http://www.wikidata.org/entity/Q125584111 | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-05-01T00:00:00Z | 2024-06-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/data/08/assessment-activity-08 | The risk of a large fire affecting the baptistery and its contents (MR = 12.5) has an extreme priority. The uncertainty that has been measured amounts to a value equal to 1.0. A risk of this magnitude is equivalent to losing about 3% of the heritage asset value every 10 years (or 30% per century, or 100% in about 300 years). The museum direction considers this level of risk as ‘not acceptable’, since as a condition the value of MR is higher than 10 and the value of uncertainty is lower than 2. | http://www.wikidata.org/entity/Q2154759   | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-05-01T00:00:00Z | 2024-06-01T23:59:59Z |
# +-----------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------+----------------------------------------------------------+--------------------------------------------------+----------------------+----------------------+
# CQ_8.5
# What are the treatment actions, capital costs and maintenance costs being referred to by the statements assigned to a CHO by treatment activities?
#
# +-----------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------+----------------------+--------------------------+----------------------------------------------------------+--------------------------------------------------+----------------------+----------------------+
# | activity                                                        | note                                                                                                                                                                                                                                                                                                                                                                | action                                  |   capital_cost_value |   maintenance_cost_value | agent                                                    | place                                            | start_date           | end_date             |
# |-----------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------+----------------------+--------------------------+----------------------------------------------------------+--------------------------------------------------+----------------------+----------------------|
# | https://w3id.org/sirius/ontology/data/08/assessment-activity-09 | One possible action to protect a baptistery from water damage could be to install a waterproof membrane or coating on the exterior surfaces. This would help prevent water infiltration and damage to the structure. Additionally, regular maintenance such as inspecting for cracks or leaks and repairing them promptly can help mitigate water damage over time. | http://www.wikidata.org/entity/Q2956685 |                 3200 |                      120 | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-06-01T00:00:00Z | 2024-07-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/data/08/assessment-activity-10 | Use fire-resistant materials: Consider using fire-resistant coatings, fire-rated doors, and fireproof insulation to minimize fire damage.                                                                                                                                                                                                                           | http://www.wikidata.org/entity/Q2956685 |                 5000 |                      375 | https://w3id.org/sirius/ontology/data/08/sara-fiorentino | https://w3id.org/sirius/ontology/data/08/ravenna | 2024-06-01T00:00:00Z | 2024-07-01T23:59:59Z |
# +-----------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------+----------------------+--------------------------+----------------------------------------------------------+--------------------------------------------------+----------------------+----------------------+
