# %%
import rdflib
from rdflib.plugins.sparql import prepareQuery
from tabulate import tabulate

# %%
filename = "ABox.ttl"

# %%
text1 = '''CQ_1
What are the statements assigned to a CHO that are part of the assessment activity describing its context?
'''

query1 = '''
PREFIX : <https://w3id.org/sirius/ontology/data/08/>
PREFIX hero: <https://w3id.org/sirius/ontology/hero/>
PREFIX ti: <http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#>
PREFIX wd: <http://www.wikidata.org/entity/>

SELECT ?statement ?note ?document ?concept ?concept_type ?activity ?agent ?place ?start_date ?end_date
WHERE {
    # ?activity a hero:Activity ;
        hero:hasType wd:Q1137655 ; 
        hero:assigns ?statement ;
        hero:hasTimeInterval [ 
            ti:hasIntervalStartDate ?start_date ;
            ti:hasIntervalEndDate ?end_date 
        ] ;
        hero:hasLocation ?place ;
        hero:isCarriedOutBy ?agent .
    # ?statement hero:hasContent ?note ;
        hero:refersTo ?concept .
    # ?concept hero:hasType ?concept_type .
    OPTIONAL {
        # ?statement hero:isDocumentedBy ?document .
    }
}

'''

# %%
text2 = '''CQ_2
Which are the hazards, the types of risk occurence and the risk locations referred to by statements assigned to a CHO by identification activities?
'''

query2 = '''
PREFIX : <https://w3id.org/sirius/ontology/data/08/>
PREFIX aat: <http://vocab.getty.edu/page/aat/>
PREFIX hero: <https://w3id.org/sirius/ontology/hero/>
PREFIX ti: <http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#>
PREFIX wd: <http://www.wikidata.org/entity/>

SELECT ?activity ?hazard_type ?occurrence_type ?location_type ?agent ?place ?start_date ?end_date
WHERE {
  # ?activity a hero:Activity ;
    hero:isCarriedOutBy ?agent ;
    hero:hasType wd:Q5687675 ;
    hero:hasTimeInterval [ 
      ti:hasIntervalStartDate ?start_date ;
      ti:hasIntervalEndDate ?end_date 
    ] ;
    hero:hasLocation ?place ;
    hero:assigns ?statement_1 ,
      # ?statement_2 ,
      # ?statement_3 .
  # ?statement_1 hero:hasType aat:300435425 ;
    hero:refersTo [
        hero:hasType ?hazard_type 
      ] .
  # ?statement_2 hero:hasType aat:300435430 ;
      hero:refersTo [
        hero:hasType ?occurrence_type 
      ] .
  # ?statement_3 hero:hasType aat:300435449 ;
      hero:refersTo [
        hero:hasType ?location_type 
      ] .
}
'''

# %%
text3 = '''CQ_3
What are the low, probable and high estimates of the measures that are referred to by statements assigned to a CHO by analysis activities?
'''

query3 = '''
PREFIX : <https://w3id.org/sirius/ontology/data/08/>
PREFIX aat: <http://vocab.getty.edu/page/aat/>
PREFIX hero: <https://w3id.org/sirius/ontology/hero/>
PREFIX ti: <http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#>
PREFIX wd: <http://www.wikidata.org/entity/>

SELECT DISTINCT ?activity ?statement ?type ?low_estimate_value ?prob_estimate_value ?high_estimate_value ?agent ?place ?start_date ?end_date
WHERE {
  # ?activity a hero:Activity ;
    hero:hasType wd:Q217602 ;
    hero:isCarriedOutBy ?agent ;
    hero:hasTimeInterval [ 
      ti:hasIntervalStartDate ?start_date ;
      ti:hasIntervalEndDate ?end_date 
    ] ;
    hero:hasLocation ?place ;
    hero:assigns ?statement .
  # ?statement hero:hasType aat:300435430 ;
    hero:refersTo ?concept .
  # ?concept hero:hasType ?type ;
    hero:hasComponent ?low_estimate ,
      # ?prob_estimate , 
      # ?high_estimate .
  # ?low_estimate hero:hasType wd:Q10585806 ;
    hero:hasContent ?low_estimate_value .
  # ?prob_estimate hero:hasType wd:Q226995 ;
    hero:hasContent ?prob_estimate_value .
  # ?high_estimate hero:hasType wd:Q10578722 ;
    hero:hasContent ?high_estimate_value .
}
'''

# %%
text4 = '''CQ_4
What are the priority levels referred to by statements assigned to a CHO by evaluation activities?
'''

query4 = '''
PREFIX : <https://w3id.org/sirius/ontology/data/08/>
PREFIX aat: <http://vocab.getty.edu/page/aat/>
PREFIX hero: <https://w3id.org/sirius/ontology/hero/>
PREFIX ti: <http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#>
PREFIX wd: <http://www.wikidata.org/entity/>

SELECT ?activity ?note ?priority_level ?agent ?place ?start_date ?end_date
WHERE {
# ?activity a hero:Activity ;
  hero:hasType wd:Q1379672 ;
  hero:hasNote ?note ;
  hero:isCarriedOutBy ?agent ;
  hero:hasTimeInterval [ 
    ti:hasIntervalStartDate ?start_date ;
    ti:hasIntervalEndDate ?end_date ] ;
  hero:hasLocation ?place ;
  hero:assigns [
    hero:hasType aat:300438433 ;
    hero:refersTo [ 
      hero:hasType ?priority_level 
    ]
  ]
}
'''

# %%
text5 = '''CQ_5
What are the treatment actions, capital costs and maintenance costs being referred to by the statements assigned to a CHO by treatment activities?
'''

query5 = '''
PREFIX : <https://w3id.org/sirius/ontology/data/08/>
PREFIX aat: <http://vocab.getty.edu/page/aat/>
PREFIX hero: <https://w3id.org/sirius/ontology/hero/>
PREFIX ti: <http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#>
PREFIX wd: <http://www.wikidata.org/entity/>

SELECT DISTINCT ?activity ?note ?action ?capital_cost_value ?maintenance_cost_value ?agent ?place ?start_date ?end_date
WHERE {
  # ?activity a hero:Activity ;
    hero:hasType wd:Q2251595 ;
    hero:hasNote ?note ;
    hero:isCarriedOutBy ?agent ;
    hero:hasTimeInterval [ 
      ti:hasIntervalStartDate ?start_date ;
      ti:hasIntervalEndDate ?end_date 
    ] ;
    hero:hasLocation ?place ;
    hero:assigns ?statement_1 ,
      # ?statement_2 ,
      # ?statement_3 .
  # ?statement_1 hero:hasType wd:Q1371819 ;
    hero:refersTo ?concept_1 .
  # ?concept_1 hero:hasType ?action .
  # ?statement_2 hero:hasType aat:300027514 ;
    hero:refersTo ?capital_cost .
  # ?capital_cost hero:hasType wd:Q302208 ;
    hero:hasContent ?capital_cost_value .
  # ?statement_3 hero:hasType aat:300027514 ;
    hero:refersTo ?maintenance_cost .
  # ?maintenance_cost hero:hasType wd:Q831940 ;
    hero:hasContent ?maintenance_cost_value .
}
'''

# %%
queries = [(text1, query1),
           (text2, query2),
           (text3, query3),
           (text4, query4),
           (text5, query5)]

g = rdflib.ConjunctiveGraph()
g.parse(filename, format="turtle", encoding="utf-8")

for query in queries:
    q = prepareQuery(query[1])
    results = g.query(q)
    print(query[0])
    table = []
    for row in results:
        table.append([row[var] for var in results.vars])
    print(tabulate(table, headers=results.vars, tablefmt="psql"))
# Out:
# CQ_1
# What are the statements assigned to a CHO that are part of the assessment activity describing its context?
#
# +------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------+--------------------------------------------------------------+-----------------------------------------+--------------------------------------------------------------------------+-------------------------------------------------------------------+-----------------------------------------------------------+----------------------+----------------------+
# | statement                                                        | note                                                                                                                                                                                                                                                                                                                                                                                                                                          | document                                                      | concept                                                      | concept_type                            | activity                                                                 | agent                                                             | place                                                     | start_date           | end_date             |
# |------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------+--------------------------------------------------------------+-----------------------------------------+--------------------------------------------------------------------------+-------------------------------------------------------------------+-----------------------------------------------------------+----------------------+----------------------|
# | https://w3id.org/sirius/ontology/hero/examples/01/observation-01 | The Classense Library in Ravenna features a blend of architectural elements that combine historical charm with modern utility. Housed within a former convent, the building's exterior reflects intricate craftsmanship typical of its era. Inside, visitors encounter spacious rooms with vaulted ceilings and simple yet elegant furnishings. The layout provides ample space for browsing through its collection of books and manuscripts. |                                                               | https://w3id.org/sirius/ontology/hero/examples/01/concept-01 | http://www.wikidata.org/entity/Q4373292 | https://w3id.org/sirius/ontology/hero/examples/01/assessment-activity-01 | https://w3id.org/sirius/ontology/hero/examples/01/sara-fiorentino | https://w3id.org/sirius/ontology/hero/examples/01/ravenna | 2024-02-01T00:00:00Z | 2024-03-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/hero/examples/01/observation-02 | The Classense Library in Ravenna holds significance within its social context as a hub for intellectual and cultural exchange. Situated in a community known for its appreciation of art and history, the library serves as a focal point for residents and visitors alike. Its presence reflects a commitment to preserving and sharing knowledge, fostering a sense of collective identity and pride.                                       |                                                               | https://w3id.org/sirius/ontology/hero/examples/01/concept-02 | http://www.wikidata.org/entity/Q8425    | https://w3id.org/sirius/ontology/hero/examples/01/assessment-activity-01 | https://w3id.org/sirius/ontology/hero/examples/01/sara-fiorentino | https://w3id.org/sirius/ontology/hero/examples/01/ravenna | 2024-02-01T00:00:00Z | 2024-03-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/hero/examples/01/observation-03 | The Classense Library in Ravenna operates within a political context that values the preservation of cultural heritage and the promotion of education. As a public institution, it receives support from local government entities committed to fostering literacy and intellectual growth.                                                                                                                                                   | https://w3id.org/sirius/ontology/hero/examples/01/document-01 | https://w3id.org/sirius/ontology/hero/examples/01/concept-03 | http://www.wikidata.org/entity/Q7163    | https://w3id.org/sirius/ontology/hero/examples/01/assessment-activity-01 | https://w3id.org/sirius/ontology/hero/examples/01/sara-fiorentino | https://w3id.org/sirius/ontology/hero/examples/01/ravenna | 2024-02-01T00:00:00Z | 2024-03-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/hero/examples/01/observation-04 | The Classense Library in Ravenna operates within a legal framework that governs its establishment, operation, and obligations as a public institution. Its legal status is defined by statutes and regulations that outline its organizational structure, funding mechanisms, and responsibilities to the community.                                                                                                                          |                                                               | https://w3id.org/sirius/ontology/hero/examples/01/concept-04 | http://www.wikidata.org/entity/Q2628882 | https://w3id.org/sirius/ontology/hero/examples/01/assessment-activity-01 | https://w3id.org/sirius/ontology/hero/examples/01/sara-fiorentino | https://w3id.org/sirius/ontology/hero/examples/01/ravenna | 2024-02-01T00:00:00Z | 2024-03-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/hero/examples/01/observation-05 | Administratively, the library is overseen by local authorities responsible for its strategic direction and resource allocation.                                                                                                                                                                                                                                                                                                               |                                                               | https://w3id.org/sirius/ontology/hero/examples/01/concept-05 | http://www.wikidata.org/entity/Q5283295 | https://w3id.org/sirius/ontology/hero/examples/01/assessment-activity-01 | https://w3id.org/sirius/ontology/hero/examples/01/sara-fiorentino | https://w3id.org/sirius/ontology/hero/examples/01/ravenna | 2024-02-01T00:00:00Z | 2024-03-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/hero/examples/01/observation-06 | Its presence contributes to the city's cultural economy, attracting visitors interested in exploring its rich literary heritage and historical significance.                                                                                                                                                                                                                                                                                  |                                                               | https://w3id.org/sirius/ontology/hero/examples/01/concept-06 | http://www.wikidata.org/entity/Q8134    | https://w3id.org/sirius/ontology/hero/examples/01/assessment-activity-01 | https://w3id.org/sirius/ontology/hero/examples/01/sara-fiorentino | https://w3id.org/sirius/ontology/hero/examples/01/ravenna | 2024-02-01T00:00:00Z | 2024-03-01T23:59:59Z |
# +------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------+--------------------------------------------------------------+-----------------------------------------+--------------------------------------------------------------------------+-------------------------------------------------------------------+-----------------------------------------------------------+----------------------+----------------------+
# CQ_8.2
# Which are the hazards, the types of risk occurence and the risk locations referred to by statements assigned to a CHO by identification activities?
#
# +--------------------------------------------------------------------------+---------------------------------------+-------------------------------------------------------------------------+-----------------------------------------+-------------------------------------------------------------------+-----------------------------------------------------------+----------------------+----------------------+
# | activity                                                                 | hazard_type                           | occurrence_type                                                         | location_type                           | agent                                                             | place                                                     | start_date           | end_date             |
# |--------------------------------------------------------------------------+---------------------------------------+-------------------------------------------------------------------------+-----------------------------------------+-------------------------------------------------------------------+-----------------------------------------------------------+----------------------+----------------------|
# | https://w3id.org/sirius/ontology/hero/examples/01/assessment-activity-03 | http://www.wikidata.org/entity/Q18663 | http://publications.europa.eu/resource/authority/frequency/QUINQUENNIAL | http://www.wikidata.org/entity/Q1058733 | https://w3id.org/sirius/ontology/hero/examples/01/sara-fiorentino | https://w3id.org/sirius/ontology/hero/examples/01/ravenna | 2024-03-01T00:00:00Z | 2024-04-01T23:59:59Z |
# +--------------------------------------------------------------------------+---------------------------------------+-------------------------------------------------------------------------+-----------------------------------------+-------------------------------------------------------------------+-----------------------------------------------------------+----------------------+----------------------+
# CQ_8.3
# What are the low, probable and high estimates of the measures that are referred to by statements assigned to a CHO by analysis activities?
#
# +--------------------------------------------------------------------------+------------------------------------------------------------------+-------------------------------------------+----------------------+-----------------------+-----------------------+-------------------------------------------------------------------+-----------------------------------------------------------+----------------------+----------------------+
# | activity                                                                 | statement                                                        | type                                      |   low_estimate_value |   prob_estimate_value |   high_estimate_value | agent                                                             | place                                                     | start_date           | end_date             |
# |--------------------------------------------------------------------------+------------------------------------------------------------------+-------------------------------------------+----------------------+-----------------------+-----------------------+-------------------------------------------------------------------+-----------------------------------------------------------+----------------------+----------------------|
# | https://w3id.org/sirius/ontology/hero/examples/01/assessment-activity-05 | https://w3id.org/sirius/ontology/hero/examples/01/observation-16 | http://www.wikidata.org/entity/Q11652     |                  2   |                   2.5 |                     3 | https://w3id.org/sirius/ontology/hero/examples/01/sara-fiorentino | https://w3id.org/sirius/ontology/hero/examples/01/ravenna | 2024-04-01T00:00:00Z | 2024-05-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/hero/examples/01/assessment-activity-05 | https://w3id.org/sirius/ontology/hero/examples/01/observation-17 | http://www.wikidata.org/entity/Q7523953   |                  4.5 |                   5   |                     5 | https://w3id.org/sirius/ontology/hero/examples/01/sara-fiorentino | https://w3id.org/sirius/ontology/hero/examples/01/ravenna | 2024-04-01T00:00:00Z | 2024-05-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/hero/examples/01/assessment-activity-05 | https://w3id.org/sirius/ontology/hero/examples/01/observation-18 | http://www.wikidata.org/entity/Q107642367 |                  4.5 |                   5   |                     5 | https://w3id.org/sirius/ontology/hero/examples/01/sara-fiorentino | https://w3id.org/sirius/ontology/hero/examples/01/ravenna | 2024-04-01T00:00:00Z | 2024-05-01T23:59:59Z |
# | https://w3id.org/sirius/ontology/hero/examples/01/assessment-activity-05 | https://w3id.org/sirius/ontology/hero/examples/01/observation-19 | http://www.wikidata.org/entity/Q2154759   |                 11   |                  12.5 |                    13 | https://w3id.org/sirius/ontology/hero/examples/01/sara-fiorentino | https://w3id.org/sirius/ontology/hero/examples/01/ravenna | 2024-04-01T00:00:00Z | 2024-05-01T23:59:59Z |
# +--------------------------------------------------------------------------+------------------------------------------------------------------+-------------------------------------------+----------------------+-----------------------+-----------------------+-------------------------------------------------------------------+-----------------------------------------------------------+----------------------+----------------------+
# CQ_8.4
# What are the priority levels referred to by statements assigned to a CHO by evaluation activities?
#
# +--------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------+-------------------------------------------------------------------+-----------------------------------------------------------+----------------------+----------------------+
# | activity                                                                 | note                                                                                                                                                                                                                                                                                                                                                                                                 | priority_level                            | agent                                                             | place                                                     | start_date           | end_date             |
# |--------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------+-------------------------------------------------------------------+-----------------------------------------------------------+----------------------+----------------------|
# | https://w3id.org/sirius/ontology/hero/examples/01/assessment-activity-07 | The risk of hardware failure (MR = 12.5) has an extreme priority. A risk of this magnitude is equivalent to losing about 3% of the heritage asset value every 10 years (or 30% per century, or 100% in about 300 years). The museum direction considers this level of risk as ‘not acceptable’, since as a condition the value of MR is higher than 10 and the value of uncertainty is lower than 2. | http://www.wikidata.org/entity/Q125584111 | https://w3id.org/sirius/ontology/hero/examples/01/sara-fiorentino | https://w3id.org/sirius/ontology/hero/examples/01/ravenna | 2024-05-01T00:00:00Z | 2024-06-01T23:59:59Z |
# +--------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------+-------------------------------------------------------------------+-----------------------------------------------------------+----------------------+----------------------+
# CQ_8.5
# What are the treatment actions, capital costs and maintenance costs being referred to by the statements assigned to a CHO by treatment activities?
#
# +--------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------+----------------------+--------------------------+-------------------------------------------------------------------+-----------------------------------------------------------+----------------------+----------------------+
# | activity                                                                 | note                                                                                                                                 | action                                  |   capital_cost_value |   maintenance_cost_value | agent                                                             | place                                                     | start_date           | end_date             |
# |--------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------+----------------------+--------------------------+-------------------------------------------------------------------+-----------------------------------------------------------+----------------------+----------------------|
# | https://w3id.org/sirius/ontology/hero/examples/01/assessment-activity-09 | Regular backups should be performed, and multiple copies of the digital collection should be stored securely in different locations. | http://www.wikidata.org/entity/Q1717246 |                 6000 |                     6000 | https://w3id.org/sirius/ontology/hero/examples/01/sara-fiorentino | https://w3id.org/sirius/ontology/hero/examples/01/ravenna | 2024-06-01T00:00:00Z | 2024-07-01T23:59:59Z |
# +--------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------+----------------------+--------------------------+-------------------------------------------------------------------+-----------------------------------------------------------+----------------------+----------------------+
